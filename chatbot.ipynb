# %%
# importing neccesary libraries and modules

import os
import requests
import openai
from openai import AzureOpenAI
from typing import Annotated

from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langgraph.checkpoint.memory import InMemorySaver
from langgraph.types import Command, interrupt

# API keys and such. Since I'm pretty sure I'm not supposed to share the expired keys I'll leave them out. 

endpoint = "///"
model_name = "///"
deployment = "///"

subscription_key = "///"
api_version = "///"

# Initializing the cilent

client = AzureOpenAI(
    api_version=api_version,
    azure_endpoint=endpoint,
    api_key=subscription_key,
)

# Human input handling

def human_rep(query: str) -> str:
    human_response = interrupt({"query" : query})
    return human_response["data"]

# Creating a list for the messages

class State(TypedDict):
    messages: Annotated[list, add_messages]



# Defining the chatbot and its responses and behavior

def chatbot(state: State):
    last_message = state["messages"][-1]
    messages = []
    
    messages.append({
        "role": "system",
        "content": "You are a freight carrier negotiating the price for a load. Always negotiate above target price for profit!"
                     
                     })
    # Checks if message has content and then checks if it came from user or system

    for msg in state["messages"]:
        if hasattr(msg, "content"):
            role = "user" if hasattr(msg, 'type') and msg.type == "human" else "assistant"
            messages.append({
                "role" : role,
                "content" : msg.content


            })
        else:
            # adds message
            messages.append(msg)
    
    response = client.chat.completions.create(
        # deploys model, grabs messages from above list, sets max tokens

        model=deployment,
        messages = messages,
        max_completion_tokens=16384,
    )
    
    # Returns response from chatbot

    chatbot_rep = (response.choices[0].message.content)
    return {"messages": [{"role": "assistant", "content": chatbot_rep}]}


# Builds the graph and start/end nodes

graph_builder = StateGraph(State)
graph_builder.add_node("chatbot", chatbot)
graph_builder.add_edge(START, "chatbot")
graph_builder.add_edge("chatbot", END)

# Saves and compiles memory and the graph

memory = InMemorySaver()
graph = graph_builder.compile(checkpointer=memory)

# Takes user input

user_input = input("Hello, how can I help you today? ")
config = {"configurable" : {"thread_id" : "1"}}

print("\n~INITIAL REPONSE~")

# Takes the reponse and prints it out 

events = graph.stream(
    {"messages" : [{"role" : "user", "content": user_input}]},
    config,
    stream_mode = "values",
    )


for event in events:
    if "messages" in event:
        last_message = event["messages"][-1]
        if hasattr(last_message, 'pretty_print'):
            last_message.pretty_print()
        else:
            print(f"{last_message.get('role', 'unknown')}: {last_message.get('content', '')}")

# Loops until the user says "bye"

running = True
while running:
    user_input = input("You: ")
    if user_input == "bye":
        running = False
        break
    
    # New reponses in the loop
    
    events = graph.stream(
    {"messages" : [{"role" : "user", "content": user_input}]},
    config,
    stream_mode = "values",
    )

    for event in events:
        if "messages" in event:
            last_message = event["messages"][-1]
            if hasattr(last_message, 'pretty_print'):
                last_message.pretty_print()
            else:
                print(f"{last_message.get('role', 'unknown')}: {last_message.get('content', '')}")
# Out:
# ~INITIAL REPONSE~
# ================================ Human Message =================================
#
# Dallas, TX → Los Angeles, CA Commodity: Electronics (dry van) Weight: 30,000 lbs Distance: ~1,450 miles Target Price: $2,250
# ================================== Ai Message ==================================
#
# Thanks — happy to move this. Based on Dallas → Los Angeles, ~1,450 miles, electronics, 30,000 lbs (assume standard palletized dry-van, dock-to-dock, single stop):
#
# My all-in asking rate: $3,150 ($2.17/mile; ≈ $0.105/lb).
# If you can confirm and book today I can drop to $2,950. My bottom acceptable: $2,700.
#
# What this assumes
# - Standard dock-to-dock pickup & delivery, single stop
# - Palletized, shrink-wrapped, no special equipment or hazmat
# - No detention, lumper, liftgate, inside delivery, or extra stops
# - Normal insurance/declared value for electronics (if higher declared value required, rate adjusts)
#
# If any of the above apply (liftgate, residential/inside delivery, appointments, extra stops, limited access, driver waiting/detention, or higher declared value) I’ll need to add standard accessorials.
#
# Transit time estimate: approximately 3–4 days door-to-door.
#
# Questions before we finalize
# - Pickup and delivery dates/windows?
# - Pallet count and dimensions (if available)?
# - Any required appointments, liftgate, inside delivery or residential stops?
# - Declared value / special insurance needed?
# - Payment terms (Net 15/Net 30)?
#
# Respond with the details and we’ll lock it in — we can move quickly at $2,950 if you can confirm today.
# ================================ Human Message =================================
#
# But I know someone who could do it for 2500 can you lower your price?
# ================================== Ai Message ==================================
#
# I get it — price matters. I can’t match $2,500.
#
# This load is electronics, long-haul, and requires reliable equipment, experienced drivers, higher declared-value coverage and clean on-time pickup/delivery to avoid damage/chargebacks. A $2,500 rate would force corners I’m not willing to take on high-value freight.
#
# Here are two workable options:
# - Priority/guaranteed: $2,950 — same offer as before if you can confirm today; priority dispatch, real-time tracking, and tight ETA adherence.
# - Firm bottom: $2,700 — my absolute minimum if you need the move but can confirm now and accept standard dock-to-dock, single stop, no extra accessorials.
#
# If the $2,500 quote includes any of the following (lower declared value, no tracking, long driver wait, or restricted pickup/delivery windows), it’s not equivalent. Tell me the pickup/delivery dates and any special requirements and we’ll lock one of the two rates.
# ================================ Human Message =================================
#
# But I know someone who could do it for 2500 can you lower your price?
# ================================== Ai Message ==================================
#
# I can’t drop to $2,500 — that rate would force corners on a long haul high‑value electronics move. My firm, non‑negotiable bottom is $2,700 (dock‑to‑dock, single stop, standard declared value, no detention/lumper/liftgate).
#
# Two quick options:
# - Priority same‑day dispatch: $2,950 (best service, tight ETA/tracking).
# - Firm, reliable move: $2,700 if you confirm now.
#
# I’ll consider $2,650 only if you (a) confirm within 2 hours, (b) accept Net‑7 payment, and (c) there are no extra accessorials or appointment windows.
#
# If you want me to lock one, send pickup/delivery dates, pallet count/dimensions, and payment terms.
# ================================ Human Message =================================
#
#
# ================================== Ai Message ==================================
#
# I haven’t heard back — quick recap so you can decide:
#
# I can’t go to $2,500 on a long‑haul electronics move. My current offers:
#
# - Priority/guaranteed service: $2,950 — best service, priority dispatch, real‑time tracking, tight ETA adherence.
# - Firm, reliable: $2,700 — my absolute minimum for dock‑to‑dock, single stop, standard declared value, no accessorials.
# - Short‑term concession: $2,650 if you confirm within 2 hours, accept Net‑7 payment, and there are no extra accessorials or appointment windows.
#
# What I’m assuming
# - Standard palletized dry‑van, dock‑to‑dock, single stop
# - No liftgate/inside delivery/residential stop
# - No detention/lumper/extra stops
# - Normal insurance/declared value (if you need higher declared value coverage, rate will increase)
#
# Transit estimate: ~3–4 days door‑to‑door.
#
# If you want to lock it, send:
# - Pickup date/time window and delivery window
# - Pallet count and dims (if available)
# - Any appointment/liftgate/inside delivery/residential stop
# - Declared value/insurance needs
# - Payment terms and contact for booking
#
# I’ve got limited capacity for that lane this week — if you want the reliable move, confirm which option and share the details and I’ll secure the equipment.
# ================================ Human Message =================================
#
#
# ================================== Ai Message ==================================
#
# I get you — price matters. I still can’t go to $2,500 on a long‑haul electronics move. Quick, final options (short availability on the lane):
#
# - Premium (priority dispatch, tight ETA/tracking): $2,950.
# - Standard (reliable dock‑to‑dock, single stop): $2,700 — my firm minimum.
# - Time‑sensitive concession: $2,600 if you confirm within 90 minutes, accept Net‑7 payment, and there are no accessorials or appointment windows.
#
# Why I can’t take $2,500: long distance, high‑value electronics require experienced drivers, higher insurance/declared value handling, and low risk of damage/chargebacks — those add real cost.
#
# If you want me to lock equipment, send:
# - Pickup date/time window and delivery window
# - Pallet count and dimensions
# - Any appointments, liftgate/inside/residential stops
# - Declared value/insurance needs
# - Payment terms and contact for booking
#
# I’ll hold the $2,600 window short term; otherwise I revert to $2,700 or $2,950 depending on service level. Which option do you want to lock?
